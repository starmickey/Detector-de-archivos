# %% [markdown]
# # Text to Excel conversor
#
# Used to convert the .txt output from `detector-py-v2.py` to an excel file

# %%
import pandas as pd
import re

# %%
# Define the input and output file paths
input_file = "data.txt"  # Change to your actual file path
output_file = "output.xlsx"

# %%
# Read the text file
with open(input_file, "r", encoding="utf-8") as file:
    lines = file.readlines()

lines
# Out:
# ['Full Path | File | Line Number | Code Line\n',
#  '--------------------------------------------------------------------------------\n',
#  '../trilay/activosfijos\\activoFijo_admin.asp | activoFijo_admin.asp | 183 | Set objpaginacion = server.CreateObject("Paging.General")\n',
#  '../trilay/activosfijos\\activosfijos_eliminar.asp | activosfijos_eliminar.asp | 101 | \'Set objpaginacion = server.CreateObject("Paging.General")\n',
#  '../trilay/activosfijos\\activosfijos_modificar.asp | activosfijos_modificar.asp | 142 | Set obj1 = server.CreateObject("DataCompactivofijo.Administracion")\n',
#  '../trilay/activosfijos\\activosfijos_modificar.asp | activosfijos_modificar.asp | 164 | Set objpaginacion = server.CreateObject("Paging.General")\n',
#  '../trilay/activosfijos\\activosfijos_modificar.asp | activosfijos_modificar.asp | 185 | Set objgeneral = server.CreateObject("DataCompactivofijo.Administracion")\n',
#  '../trilay/activosfijos\\Activosfijos_nuevo.asp | Activosfijos_nuevo.asp | 33 | Set objgeneral = server.CreateObject("DataCompactivofijo.Administracion")\n',
#  '../trilay/activosfijos\\activosfijos_nuevo1.asp | activosfijos_nuevo1.asp | 174 | Set objgeneral = server.CreateObject("DataCompactivofijo.Administracion")\n',
#  '../trilay/activosfijos\\activos_estado.asp | activos_estado.asp | 171 | Set objactivo = Server.CreateObject("DataCompActivoFijo.Administracion")\n',
#  '../trilay/activosfijos\\activo_reevaluar.asp | activo_reevaluar.asp | 196 | Set objtabla1 = Server.CreateObject("DataCompactivofijo.administracion")\n',
#  '../trilay/activosfijos\\administracion.asp | administracion.asp | 789 | Set objorg = Server.CreateObject("DataComporganigrama.organigrama")\n',
#  '../trilay/activosfijos\\administracion.asp | administracion.asp | 810 | Set objDocument = Server.CreateObject("Microsoft.XMLDOM")\n',
#  '../trilay/activosfijos\\Ajuste_Stock.vb.asp | Ajuste_Stock.vb.asp | 74 | Set ObjAF = Server.CreateObject("DataCompActivoFijo.administracion")\n',
#  '../trilay/activosfijos\\Ajuste_Stock.vb.asp | Ajuste_Stock.vb.asp | 363 | Set OBJ = Server.CreateObject("DataCompSelect.clasegeneral")\n',
#  '../trilay/activosfijos\\almacen_modificar.asp | almacen_modificar.asp | 163 | Set objtabla2 = server.CreateObject("DataCompActivoFijo.administracion")\n',
#  '../trilay/activosfijos\\almacen_nuevo.asp | almacen_nuevo.asp | 161 | <%Set objtabla2 = server.CreateObject("DataCompActivoFijo.Administracion")\n',
#  '../trilay/activosfijos\\arbolrubro - Copy.asp | arbolrubro - Copy.asp | 75 | Set objorg = Server.CreateObject("DataCompActivoFijo.organigrama")\n',
#  '../trilay/activosfijos\\arbolrubro - Copy.asp | arbolrubro - Copy.asp | 189 | Set objDocument = Server.CreateObject("Microsoft.XMLDOM")\n',
#  '../trilay/activosfijos\\arbolrubro.asp | arbolrubro.asp | 114 | Set objorg = Server.CreateObject("DataCompActivoFijo.organigrama")\n',
#  '../trilay/activosfijos\\arbolrubro1.asp | arbolrubro1.asp | 84 | Set objDocument = Server.CreateObject("Microsoft.XMLDOM")\n',
#  '../trilay/activosfijos\\ArbolRubros Copy.asp | ArbolRubros Copy.asp | 65 | Set objorg = Server.CreateObject("DataCompProduccion.articulo")\n',
#  '../trilay/activosfijos\\ArbolRubros Copy.asp | ArbolRubros Copy.asp | 69 | Set objorg = Server.CreateObject("DataCompInventario.organigrama")\n',
#  '../trilay/activosfijos\\ArbolRubros Copy.asp | ArbolRubros Copy.asp | 111 | Set objDocument = Server.CreateObject("Microsoft.XMLDOM")\n',
#  '../trilay/activosfijos\\ArbolRubros.asp | ArbolRubros.asp | 4 | Set objorg = Server.CreateObject("DataCompActivoFijo.organigrama")\n',
#  '../trilay/activosfijos\\articulojerarquia_modificar.asp | articulojerarquia_modificar.asp | 145 | Set objtabla1 = server.CreateObject("DataCompactivofijo.administracion")\n',
#  '../trilay/activosfijos\\articulojerarquia_modificar.asp | articulojerarquia_modificar.asp | 181 | Set objgeneral = server.CreateObject("DataCompcompras.Administracion")\n',
#  '../trilay/activosfijos\\articulojerarquia_modificar.asp | articulojerarquia_modificar.asp | 275 | \'Set objpaginacion = server.CreateObject("Paging.General")\n',
#  '../trilay/activosfijos\\articulojerarquia_nuevo.asp | articulojerarquia_nuevo.asp | 44 | Set objtabla1 = server.CreateObject("DataCompactivofijo.administracion")\n',
#  '../trilay/activosfijos\\articulojerarquia_nuevo.asp | articulojerarquia_nuevo.asp | 69 | Set objgeneral = server.CreateObject("DataCompcompras.Administracion")\n',
#  '../trilay/activosfijos\\articulojerarquia_nuevo1.asp | articulojerarquia_nuevo1.asp | 226 | Set objtabla1 = server.CreateObject("DataCompactivofijo.administracion")\n',
#  '../trilay/activosfijos\\articulojerarquia_nuevo1.asp | articulojerarquia_nuevo1.asp | 256 | Set objpaginacion = server.CreateObject("Paging.General")\n',
#  '../trilay/activosfijos\\articulojerarquia_stock.asp | articulojerarquia_stock.asp | 108 | Set objtabla1 = server.CreateObject("DataCompactivofijo.administracion")\n',
#  '../trilay/activosfijos\\articulojerarquia_stock.asp | articulojerarquia_stock.asp | 120 | Set objgeneral = server.CreateObject("DataCompcompras.Administracion")\n',
#  '../trilay/activosfijos\\articulo_admin.asp | articulo_admin.asp | 214 | Set objpaginacion = server.CreateObject("Paging.General")\n',
#  '../trilay/activosfijos\\articulo_eliminar.asp | articulo_eliminar.asp | 97 | Set objp = server.CreateObject("DataCompActivoFijo.Organigrama")\n',
#  '../trilay/activosfijos\\articulo_eliminar.asp | articulo_eliminar.asp | 143 | Set objpaginacion = server.CreateObject("Paging.General")\n',
#  '../trilay/activosfijos\\articulo_nuevo.asp | articulo_nuevo.asp | 44 | Set objtabla1 = server.CreateObject("DataCompactivofijo.administracion")\n',
#  '../trilay/activosfijos\\articulo_nuevo.asp | articulo_nuevo.asp | 74 | Set objgeneral = server.CreateObject("DataCompcompras.Administracion")\n',
#  '../trilay/activosfijos\\articulo_seleccion1.asp | articulo_seleccion1.asp | 69 | Set objorg = Server.CreateObject("DataCompactivofijo.organigrama")\n',
#  '../trilay/activosfijos\\articulo_seleccion1.asp | articulo_seleccion1.asp | 241 | Set objDocument = Server.CreateObject("Microsoft.XMLDOM")\n',
#  '../trilay/activosfijos\\articulo_stock.asp | articulo_stock.asp | 122 | Set objtabla1=server.CreateObject("DataCompactivofijo.administracion")\n',
#  '../trilay/activosfijos\\articulo_stock.asp | articulo_stock.asp | 125 | Set objgeneral=server.CreateObject("DataCompcompras.Administracion")\n',
#  '../trilay/activosfijos\\articulo_stock1.asp | articulo_stock1.asp | 31 | Set objgeneral = server.CreateObject("DataCompcompras.Administracion")\n',
#  '../trilay/activosfijos\\autorizar_salida1.asp | autorizar_salida1.asp | 13 | Set ObjAF = Server.CreateObject("DataCompActivofijo.Administracion")\n',
#  '../trilay/activosfijos\\autorizar_salida1.asp | autorizar_salida1.asp | 288 | Set objtabla = Server.CreateObject("DataCompActivofijo.Administracion")\n',
#  '../trilay/activosfijos\\autorizar_salida1.asp | autorizar_salida1.asp | 330 | Set objtabla1 = Server.CreateObject("DataComprequerimiento.Requerimiento")\n',
#  '../trilay/activosfijos\\autorizar_salida1.asp | autorizar_salida1.asp | 494 | Set objmov = Server.CreateObject("DataCompFondos.Administracion")\n',
#  '../trilay/activosfijos\\autorizar_salida1.asp | autorizar_salida1.asp | 513 | \'Set objtabla1 = Server.CreateObject("DataComprequerimiento.Requerimiento")\n',
#  '../trilay/activosfijos\\comodato_ifr.asp | comodato_ifr.asp | 29 | Set objtabla = server.CreateObject("DataCompActivofijo.administracion")\n',
#  '../trilay/activosfijos\\concepto_admin1.asp | concepto_admin1.asp | 31 | Set objtabla = server.CreateObject("DataCompActivoFijo.administracion")\n',
#  '../trilay/activosfijos\\Detalle_Remito_Gral.asp | Detalle_Remito_Gral.asp | 6 | Set CONN = Server.CreateObject("DataCompSelect.ClaseGeneral")\n',
#  '../trilay/activosfijos\\Detalle_Remito_Gral.asp | Detalle_Remito_Gral.asp | 21 | Set objcarpeta = Server.CreateObject("DataCompAdjuntos.Adjuntos")\n',
#  '../trilay/activosfijos\\entrega_aft1.asp | entrega_aft1.asp | 13 | Set obj3 = Server.CreateObject("DataCompActivofijo.Administracion")\n',
#  '../trilay/activosfijos\\Escritorio_Insumos.asp | Escritorio_Insumos.asp | 56 | SET OBJ = Server.CreateObject("DataCompActivoFijo.Administracion")\n',
#  '../trilay/activosfijos\\Escritorio_Insumos.vb.asp | Escritorio_Insumos.vb.asp | 52 | SET OBJ = Server.CreateObject("DataCompActivoFijo.Administracion")\n',
#  '../trilay/activosfijos\\Escritorio_Insumos.vb.asp | Escritorio_Insumos.vb.asp | 133 | SET OBJ = Server.CreateObject("DataCompActivoFijo.Administracion")\n',
#  '../trilay/activosfijos\\Escritorio_Insumos.vb.asp | Escritorio_Insumos.vb.asp | 206 | SET OBJ = Server.CreateObject("DataCompActivoFijo.Administracion")\n',
#  '../trilay/activosfijos\\Escritorio_Insumos.vb.asp | Escritorio_Insumos.vb.asp | 255 | SET OBJ = Server.CreateObject("DataCompActivoFijo.Administracion")\n',
#  '../trilay/activosfijos\\Escritorio_Insumos.vb.asp | Escritorio_Insumos.vb.asp | 313 | SET OBJ = Server.CreateObject("DataCompActivoFijo.Administracion")\n',
#  '../trilay/activosfijos\\Escritorio_Insumos.vb.asp | Escritorio_Insumos.vb.asp | 987 | SET OBJ = Server.CreateObject("DataCompActivoFijo.Administracion")\n',
#  '../trilay/activosfijos\\estados_modificar.asp | estados_modificar.asp | 69 | Set objgeneral = server.CreateObject("DataCompactivofijo.Administracion")\n',
#  '../trilay/activosfijos\\estados_nuevo.asp | estados_nuevo.asp | 76 | Set objgeneral = server.CreateObject("DataCompactivofijo.Administracion")\n',
#  '../trilay/activosfijos\\estado_admin1.asp | estado_admin1.asp | 32 | Set objtabla2 = server.CreateObject("DataCompActivoFijo.Administracion")\n',
#  '../trilay/activosfijos\\grafico_traslado1.asp | grafico_traslado1.asp | 76 | Set Chart = Server.CreateObject("AspChart.Chart")\n',
#  '../trilay/activosfijos\\Ingreso_Directo.vb.asp | Ingreso_Directo.vb.asp | 59 | Set ObjAF = Server.CreateObject("DataCompActivoFijo.administracion")\n',
#  '../trilay/activosfijos\\Ingreso_Directo.vb.asp | Ingreso_Directo.vb.asp | 311 | Set OBJ = Server.CreateObject("DataCompSelect.clasegeneral")\n',
#  '../trilay/activosfijos\\ingreso_directo_afc1.asp | ingreso_directo_afc1.asp | 40 | Set objcmpc = Server.CreateObject("DataCompCompras.compras")\n',
#  '../trilay/activosfijos\\ingreso_directo_afc1.asp | ingreso_directo_afc1.asp | 43 | set objcomp = Server.CreateObject("DataCompCompras.compras")\n',
#  '../trilay/activosfijos\\ingreso_directo_afc1.asp | ingreso_directo_afc1.asp | 46 | set obj = Server.CreateObject("DataCompCompras.compras")\n',
#  '../trilay/activosfijos\\ingreso_directo_afc1.asp | ingreso_directo_afc1.asp | 49 | Set objtabla3 = Server.CreateObject("DataCompCompras.Compras")\n',
#  '../trilay/activosfijos\\ingreso_directo_afc1.asp | ingreso_directo_afc1.asp | 355 | Set objmov = Server.CreateObject("DataCompFondos.Administracion")\n',
#  '../trilay/activosfijos\\inicial Copy.asp | inicial Copy.asp | 55 | Set objtabla1 = Server.CreateObject("DataCompActivofijo.Administracion")\n',
#  '../trilay/activosfijos\\inicial Copy.asp | inicial Copy.asp | 267 | Set objDocument = Server.CreateObject("Microsoft.XMLDOM")\n',
#  '../trilay/activosfijos\\inicialB Copy.asp | inicialB Copy.asp | 55 | Set objtabla1 = Server.CreateObject("DataCompActivofijo.Administracion")\n',
#  '../trilay/activosfijos\\inicialB Copy.asp | inicialB Copy.asp | 257 | Set objDocument = Server.CreateObject("Microsoft.XMLDOM")\n',
#  '../trilay/activosfijos\\inicialB.asp | inicialB.asp | 36 | Set objtabla1 = Server.CreateObject("DataCompActivofijo.Administracion")\n',
#  '../trilay/activosfijos\\intercambio_compras1.asp | intercambio_compras1.asp | 301 | Set objtabla1 = Server.CreateObject("DataComprequerimiento.Requerimiento")\n',
#  '../trilay/activosfijos\\intercambio_compras1.asp | intercambio_compras1.asp | 304 | Set objcarpeta = Server.CreateObject("DataCompAdjuntos.Adjuntos")\n',
#  '../trilay/activosfijos\\intercambio_compras1.asp | intercambio_compras1.asp | 306 | Set obja = Server.CreateObject("DataCompABC.abc")\n',
#  '../trilay/activosfijos\\intercambio_compras1.asp | intercambio_compras1.asp | 310 | Set objtabla3 = Server.CreateObject("DataCompCompras.Compras")\n',
#  '../trilay/activosfijos\\intercambio_comprasVIEJO.asp | intercambio_comprasVIEJO.asp | 326 | Set objtabla1 = Server.CreateObject("DataComprequerimiento.Requerimiento")\n',
#  '../trilay/activosfijos\\intercambio_comprasVIEJO.asp | intercambio_comprasVIEJO.asp | 329 | \'Set objcarpeta = Server.CreateObject("DataCompAdjuntos.Adjuntos")\n',
#  '../trilay/activosfijos\\intercambio_comprasVIEJO.asp | intercambio_comprasVIEJO.asp | 333 | Set objcomp = Server.CreateObject("DataCompCompras.Compras")\n',
#  '../trilay/activosfijos\\intercambio_comprasVIEJO.asp | intercambio_comprasVIEJO.asp | 336 | Set objtabla3 = Server.CreateObject("DataCompCompras.Compras")\n',
#  '../trilay/activosfijos\\intercambio_Compras_ifr.asp | intercambio_Compras_ifr.asp | 28 | Set objcomp = Server.CreateObject("DataCompCompras.Compras")\n',
#  '../trilay/activosfijos\\listado_fletes.asp | listado_fletes.asp | 8 | Set obj1 = Server.CreateObject("DataCompProduccion.Flete")\n',
#  '../trilay/activosfijos\\listado_lotes.asp | listado_lotes.asp | 47 | Set obj1 = Server.CreateObject("DataCompProduccion.Lote")\n',
#  '../trilay/activosfijos\\listado_lotes.asp | listado_lotes.asp | 63 | Set objmov = Server.CreateObject("DataCompFondos.Administracion")\n',
#  '../trilay/activosfijos\\listado_lotes2.asp | listado_lotes2.asp | 8 | Set obj1 = Server.CreateObject("DataCompProduccion.Lote")\n',
#  '../trilay/activosfijos\\listado_lotes2.asp | listado_lotes2.asp | 44 | Set objmov = Server.CreateObject("DataCompFondos.Administracion")\n',
#  '../trilay/activosfijos\\listado_remitos.asp | listado_remitos.asp | 53 | Set Conn = Server.CreateObject("datacompInventario.GESTION_BD")\n',
#  '../trilay/activosfijos\\listado_remitos.asp | listado_remitos.asp | 189 | Set objmov = Server.CreateObject("DataCompFondos.Administracion")\n',
#  '../trilay/activosfijos\\listaproveedores.asp | listaproveedores.asp | 406 | Set objtabla2 = server.CreateObject("DataCompproveedores.administracion")\n',
#  '../trilay/activosfijos\\organigramarubro.asp | organigramarubro.asp | 78 | Set objorg = Server.CreateObject("DataCompActivoFijo.Organigrama")\n',
#  '../trilay/activosfijos\\organigramarubro.asp | organigramarubro.asp | 90 | Set objDocument = Server.CreateObject("Microsoft.XMLDOM")\n',
#  '../trilay/activosfijos\\organigramarubro1 Copy.asp | organigramarubro1 Copy.asp | 223 | Set objtabla = Server.CreateObject("DataCompActivoFijo.Organigrama")\n',
#  '../trilay/activosfijos\\organigramarubro1 Copy.asp | organigramarubro1 Copy.asp | 227 | Set objorg = Server.CreateObject("DataCompActivoFijo.organigrama")\n',
#  '../trilay/activosfijos\\organigramarubro1 Copy.asp | organigramarubro1 Copy.asp | 247 | Set objDocument = Server.CreateObject("Microsoft.XMLDOM")\n',
#  '../trilay/activosfijos\\organigramarubro1.asp | organigramarubro1.asp | 4 | Set objtabla = Server.CreateObject("DataCompActivoFijo.Organigrama")\n',
#  '../trilay/activosfijos\\orgpermiso.asp | orgpermiso.asp | 83 | Set objDocument = Server.CreateObject("Microsoft.XMLDOM")\n',
#  '../trilay/activosfijos\\orgrubroafc.asp | orgrubroafc.asp | 54 | Set objorg = Server.CreateObject("DataCompActivoFijo.Organigrama")\n',
#  '../trilay/activosfijos\\orgrubroafc.asp | orgrubroafc.asp | 68 | Set objDocument = Server.CreateObject("Microsoft.XMLDOM")\n',
#  '../trilay/activosfijos\\orgrubro_i.asp | orgrubro_i.asp | 35 | set obj1=server.CreateObject("DataCompActivoFijo.Administracion")\n',
#  '../trilay/activosfijos\\preciosIns_admin1.asp | preciosIns_admin1.asp | 40 | \'Set obj_Datos = Server.CreateObject("DataCompActivoFijo.Administracion")\n',
#  '../trilay/activosfijos\\precios_admin.asp | precios_admin.asp | 194 | <%Set obj_Datos = Server.CreateObject("Paging.General")\n',
#  '../trilay/activosfijos\\precios_admin1.asp | precios_admin1.asp | 42 | Set obj_Datos = Server.CreateObject("DataCompActivoFijo.Administracion")\n',
#  '../trilay/activosfijos\\remito_detalle.asp | remito_detalle.asp | 12 | Set CONN = Server.CreateObject("DataCompSelect.ClaseGeneral")\n',
#  '../trilay/activosfijos\\reporte_fletes.asp | reporte_fletes.asp | 17 | Set Conn = Server.CreateObject("DataCompSelect.ClaseGeneral")\n',
#  '../trilay/activosfijos\\resultados_exportar2.asp | resultados_exportar2.asp | 5 | Set obj = Server.CreateObject("DataCompExportarHTML.exportar")\n',
#  '../trilay/activosfijos\\rptmovimiento.asp | rptmovimiento.asp | 32 | set bdd=server.CreateObject("DataCompselect.ClaseGeneral")\n',
#  '../trilay/activosfijos\\rptmovimiento_detallado.asp | rptmovimiento_detallado.asp | 63 | set bdd=server.CreateObject("DataCompSelect.ClaseGeneral")\n',
#  '../trilay/activosfijos\\rubrosjerarquia Copy.asp | rubrosjerarquia Copy.asp | 141 | Set objorg = Server.CreateObject("DataCompActivoFijo.organigrama")\n',
#  '../trilay/activosfijos\\rubrosjerarquia Copy.asp | rubrosjerarquia Copy.asp | 745 | Set objDocument = Server.CreateObject("Microsoft.XMLDOM")\n',
#  '../trilay/activosfijos\\rubros_admin Copy.asp | rubros_admin Copy.asp | 426 | Set objorg = Server.CreateObject("DataCompActivoFijo.Organigrama")\n',
#  '../trilay/activosfijos\\rubros_admin Copy.asp | rubros_admin Copy.asp | 465 | Set objDocument = Server.CreateObject("Microsoft.XMLDOM")\n',
#  '../trilay/activosfijos\\rubros_admin.asp | rubros_admin.asp | 17 | set objtabla= Server.CreateObject("DataCompActivoFijo.Organigrama")\n',
#  '../trilay/activosfijos\\rubros_eliminar.asp | rubros_eliminar.asp | 59 | Set objp = server.CreateObject("DataCompactivofijo.organigrama")\n',
#  '../trilay/activosfijos\\rubros_modificar.asp | rubros_modificar.asp | 20 | Set objp = server.CreateObject("DataCompActivoFijo.organigrama")\n',
#  '../trilay/activosfijos\\rubros_nuevo.asp | rubros_nuevo.asp | 25 | Set objp = server.CreateObject("DataCompActivoFijo.organigrama")\n',
#  '../trilay/activosfijos\\rubros_nuevo1.asp | rubros_nuevo1.asp | 36 | Set objp = server.CreateObject("DataCompActivoFijo.organigrama")\n',
#  '../trilay/activosfijos\\rubros_nuevo1.asp | rubros_nuevo1.asp | 44 | Set obja = server.CreateObject("DataCompActivoFijo.Administracion")\n',
#  '../trilay/activosfijos\\Salida_Directa.vb.asp | Salida_Directa.vb.asp | 63 | Set ObjAF = Server.CreateObject("DataCompActivoFijo.administracion")\n',
#  '../trilay/activosfijos\\sel_articulojerarquia_nuevo.asp | sel_articulojerarquia_nuevo.asp | 135 | Set objtabla1 = server.CreateObject("DataCompactivofijo.administracion")\n',
#  '../trilay/activosfijos\\sel_articulojerarquia_nuevo.asp | sel_articulojerarquia_nuevo.asp | 173 | Set objgeneral = server.CreateObject("DataCompcompras.Administracion")\n',
#  '../trilay/activosfijos\\sel_articulopropio.asp | sel_articulopropio.asp | 138 | Set objtabla1 = server.CreateObject("DataCompactivofijo.administracion")\n',
#  '../trilay/activosfijos\\sel_articulopropio.asp | sel_articulopropio.asp | 178 | Set objgeneral = server.CreateObject("DataCompcompras.Administracion")\n',
#  '../trilay/activosfijos\\sel_articulo_nuevo.asp | sel_articulo_nuevo.asp | 9 | Set objtabla = Server.CreateObject("DataCompCompras.Compras")\n',
#  '../trilay/activosfijos\\sel_articulo_nuevo_ifr.asp | sel_articulo_nuevo_ifr.asp | 10 | Set objtabla = Server.CreateObject("DataCompCompras.Compras")\n',
#  '../trilay/activosfijos\\sel_articulo_seleccion1.asp | sel_articulo_seleccion1.asp | 65 | Set objorg = Server.CreateObject("DataCompactivofijo.organigrama")\n',
#  '../trilay/activosfijos\\sel_articulo_seleccion1.asp | sel_articulo_seleccion1.asp | 214 | Set objDocument = Server.CreateObject("Microsoft.XMLDOM")\n',
#  '../trilay/activosfijos\\stockinsumosprod_admin.asp | stockinsumosprod_admin.asp | 11 | Set objcarpeta = Server.CreateObject("DataCompAdjuntos.Adjuntos")\n',
#  '../trilay/activosfijos\\stockinsumosprod_admin_old.asp | stockinsumosprod_admin_old.asp | 15 | Set objcarpeta = Server.CreateObject("DataCompAdjuntos.Adjuntos")\n',
#  '../trilay/activosfijos\\Transformacion_Productos.vb.asp | Transformacion_Productos.vb.asp | 48 | Set ObjInv = New Conexion\'Server.CreateObject("DataCompInventario.administracion")\n',
#  '../trilay/activosfijos\\Traslado_Insumos.vb.asp | Traslado_Insumos.vb.asp | 31 | Set ObjAF = Server.CreateObject("DataCompActivoFijo.administracion")\n',
#  '../trilay/activosfijos\\Traslado_Insumos.vb.asp | Traslado_Insumos.vb.asp | 285 | Set OBJ = Server.CreateObject("DataCompActivoFijo.administracion")\n',
#  '../trilay/activosfijos\\Traslado_Insumos.vb.asp | Traslado_Insumos.vb.asp | 418 | Set OBJ = Server.CreateObject("DataCompActivoFijo.administracion")\n',
#  '../trilay/activosfijos\\Traslado_Insumos.vb.asp | Traslado_Insumos.vb.asp | 716 | Set Conn = Server.CreateObject("datacompInventario.GESTION_BD")\n',
#  '../trilay/activosfijos\\Traslado_Insumos_Especial.vb.asp | Traslado_Insumos_Especial.vb.asp | 40 | Set ObjAF = Server.CreateObject("DataCompActivoFijo.administracion")\n',
#  '../trilay/activosfijos\\Traslado_Insumos_Especial.vb.asp | Traslado_Insumos_Especial.vb.asp | 526 | Set Conn = New Conexion\'Server.CreateObject("datacompInventario.GESTION_BD")\n',
#  '../trilay/activosfijos\\Reporte\\AlwaysRequiredSteps.asp | AlwaysRequiredSteps.asp | 21 | Set session("oApp") = Server.CreateObject("CrystalRuntime.Application")\n',
#  '../trilay/activosfijos\\Reporte\\rptserver.asp | rptserver.asp | 71 | Set session("oEMF") = Server.CreateObject("CREmfgen.CREmfgen.1")\n']

# %%
# Initialize a list to store parsed data
data = []

# Define regex pattern to extract required information
pattern = re.compile(r"^(.+?)\s+\|\s+(.+?)\s+\|\s+(\d+)\s+\|\s+(.+)$")

# Process each line after the header
for line in lines[2:]:  # Skip the first two lines (headers and separator)
    match = pattern.match(line.strip())
    if match:
        full_path, file_name, line_number, code_line = match.groups()
        data.append([full_path.strip(), file_name.strip(), int(line_number.strip()), code_line.strip()])
data
# Out:
# [['../trilay/activosfijos\\activoFijo_admin.asp',
#   'activoFijo_admin.asp',
#   183,
#   'Set objpaginacion = server.CreateObject("Paging.General")'],
#  ['../trilay/activosfijos\\activosfijos_eliminar.asp',
#   'activosfijos_eliminar.asp',
#   101,
#   '\'Set objpaginacion = server.CreateObject("Paging.General")'],
#  ['../trilay/activosfijos\\activosfijos_modificar.asp',
#   'activosfijos_modificar.asp',
#   142,
#   'Set obj1 = server.CreateObject("DataCompactivofijo.Administracion")'],
#  ['../trilay/activosfijos\\activosfijos_modificar.asp',
#   'activosfijos_modificar.asp',
#   164,
#   'Set objpaginacion = server.CreateObject("Paging.General")'],
#  ['../trilay/activosfijos\\activosfijos_modificar.asp',
#   'activosfijos_modificar.asp',
#   185,
#   'Set objgeneral = server.CreateObject("DataCompactivofijo.Administracion")'],
#  ['../trilay/activosfijos\\Activosfijos_nuevo.asp',
#   'Activosfijos_nuevo.asp',
#   33,
#   'Set objgeneral = server.CreateObject("DataCompactivofijo.Administracion")'],
#  ['../trilay/activosfijos\\activosfijos_nuevo1.asp',
#   'activosfijos_nuevo1.asp',
#   174,
#   'Set objgeneral = server.CreateObject("DataCompactivofijo.Administracion")'],
#  ['../trilay/activosfijos\\activos_estado.asp',
#   'activos_estado.asp',
#   171,
#   'Set objactivo = Server.CreateObject("DataCompActivoFijo.Administracion")'],
#  ['../trilay/activosfijos\\activo_reevaluar.asp',
#   'activo_reevaluar.asp',
#   196,
#   'Set objtabla1 = Server.CreateObject("DataCompactivofijo.administracion")'],
#  ['../trilay/activosfijos\\administracion.asp',
#   'administracion.asp',
#   789,
#   'Set objorg = Server.CreateObject("DataComporganigrama.organigrama")'],
#  ['../trilay/activosfijos\\administracion.asp',
#   'administracion.asp',
#   810,
#   'Set objDocument = Server.CreateObject("Microsoft.XMLDOM")'],
#  ['../trilay/activosfijos\\Ajuste_Stock.vb.asp',
#   'Ajuste_Stock.vb.asp',
#   74,
#   'Set ObjAF = Server.CreateObject("DataCompActivoFijo.administracion")'],
#  ['../trilay/activosfijos\\Ajuste_Stock.vb.asp',
#   'Ajuste_Stock.vb.asp',
#   363,
#   'Set OBJ = Server.CreateObject("DataCompSelect.clasegeneral")'],
#  ['../trilay/activosfijos\\almacen_modificar.asp',
#   'almacen_modificar.asp',
#   163,
#   'Set objtabla2 = server.CreateObject("DataCompActivoFijo.administracion")'],
#  ['../trilay/activosfijos\\almacen_nuevo.asp',
#   'almacen_nuevo.asp',
#   161,
#   '<%Set objtabla2 = server.CreateObject("DataCompActivoFijo.Administracion")'],
#  ['../trilay/activosfijos\\arbolrubro - Copy.asp',
#   'arbolrubro - Copy.asp',
#   75,
#   'Set objorg = Server.CreateObject("DataCompActivoFijo.organigrama")'],
#  ['../trilay/activosfijos\\arbolrubro - Copy.asp',
#   'arbolrubro - Copy.asp',
#   189,
#   'Set objDocument = Server.CreateObject("Microsoft.XMLDOM")'],
#  ['../trilay/activosfijos\\arbolrubro.asp',
#   'arbolrubro.asp',
#   114,
#   'Set objorg = Server.CreateObject("DataCompActivoFijo.organigrama")'],
#  ['../trilay/activosfijos\\arbolrubro1.asp',
#   'arbolrubro1.asp',
#   84,
#   'Set objDocument = Server.CreateObject("Microsoft.XMLDOM")'],
#  ['../trilay/activosfijos\\ArbolRubros Copy.asp',
#   'ArbolRubros Copy.asp',
#   65,
#   'Set objorg = Server.CreateObject("DataCompProduccion.articulo")'],
#  ['../trilay/activosfijos\\ArbolRubros Copy.asp',
#   'ArbolRubros Copy.asp',
#   69,
#   'Set objorg = Server.CreateObject("DataCompInventario.organigrama")'],
#  ['../trilay/activosfijos\\ArbolRubros Copy.asp',
#   'ArbolRubros Copy.asp',
#   111,
#   'Set objDocument = Server.CreateObject("Microsoft.XMLDOM")'],
#  ['../trilay/activosfijos\\ArbolRubros.asp',
#   'ArbolRubros.asp',
#   4,
#   'Set objorg = Server.CreateObject("DataCompActivoFijo.organigrama")'],
#  ['../trilay/activosfijos\\articulojerarquia_modificar.asp',
#   'articulojerarquia_modificar.asp',
#   145,
#   'Set objtabla1 = server.CreateObject("DataCompactivofijo.administracion")'],
#  ['../trilay/activosfijos\\articulojerarquia_modificar.asp',
#   'articulojerarquia_modificar.asp',
#   181,
#   'Set objgeneral = server.CreateObject("DataCompcompras.Administracion")'],
#  ['../trilay/activosfijos\\articulojerarquia_modificar.asp',
#   'articulojerarquia_modificar.asp',
#   275,
#   '\'Set objpaginacion = server.CreateObject("Paging.General")'],
#  ['../trilay/activosfijos\\articulojerarquia_nuevo.asp',
#   'articulojerarquia_nuevo.asp',
#   44,
#   'Set objtabla1 = server.CreateObject("DataCompactivofijo.administracion")'],
#  ['../trilay/activosfijos\\articulojerarquia_nuevo.asp',
#   'articulojerarquia_nuevo.asp',
#   69,
#   'Set objgeneral = server.CreateObject("DataCompcompras.Administracion")'],
#  ['../trilay/activosfijos\\articulojerarquia_nuevo1.asp',
#   'articulojerarquia_nuevo1.asp',
#   226,
#   'Set objtabla1 = server.CreateObject("DataCompactivofijo.administracion")'],
#  ['../trilay/activosfijos\\articulojerarquia_nuevo1.asp',
#   'articulojerarquia_nuevo1.asp',
#   256,
#   'Set objpaginacion = server.CreateObject("Paging.General")'],
#  ['../trilay/activosfijos\\articulojerarquia_stock.asp',
#   'articulojerarquia_stock.asp',
#   108,
#   'Set objtabla1 = server.CreateObject("DataCompactivofijo.administracion")'],
#  ['../trilay/activosfijos\\articulojerarquia_stock.asp',
#   'articulojerarquia_stock.asp',
#   120,
#   'Set objgeneral = server.CreateObject("DataCompcompras.Administracion")'],
#  ['../trilay/activosfijos\\articulo_admin.asp',
#   'articulo_admin.asp',
#   214,
#   'Set objpaginacion = server.CreateObject("Paging.General")'],
#  ['../trilay/activosfijos\\articulo_eliminar.asp',
#   'articulo_eliminar.asp',
#   97,
#   'Set objp = server.CreateObject("DataCompActivoFijo.Organigrama")'],
#  ['../trilay/activosfijos\\articulo_eliminar.asp',
#   'articulo_eliminar.asp',
#   143,
#   'Set objpaginacion = server.CreateObject("Paging.General")'],
#  ['../trilay/activosfijos\\articulo_nuevo.asp',
#   'articulo_nuevo.asp',
#   44,
#   'Set objtabla1 = server.CreateObject("DataCompactivofijo.administracion")'],
#  ['../trilay/activosfijos\\articulo_nuevo.asp',
#   'articulo_nuevo.asp',
#   74,
#   'Set objgeneral = server.CreateObject("DataCompcompras.Administracion")'],
#  ['../trilay/activosfijos\\articulo_seleccion1.asp',
#   'articulo_seleccion1.asp',
#   69,
#   'Set objorg = Server.CreateObject("DataCompactivofijo.organigrama")'],
#  ['../trilay/activosfijos\\articulo_seleccion1.asp',
#   'articulo_seleccion1.asp',
#   241,
#   'Set objDocument = Server.CreateObject("Microsoft.XMLDOM")'],
#  ['../trilay/activosfijos\\articulo_stock.asp',
#   'articulo_stock.asp',
#   122,
#   'Set objtabla1=server.CreateObject("DataCompactivofijo.administracion")'],
#  ['../trilay/activosfijos\\articulo_stock.asp',
#   'articulo_stock.asp',
#   125,
#   'Set objgeneral=server.CreateObject("DataCompcompras.Administracion")'],
#  ['../trilay/activosfijos\\articulo_stock1.asp',
#   'articulo_stock1.asp',
#   31,
#   'Set objgeneral = server.CreateObject("DataCompcompras.Administracion")'],
#  ['../trilay/activosfijos\\autorizar_salida1.asp',
#   'autorizar_salida1.asp',
#   13,
#   'Set ObjAF = Server.CreateObject("DataCompActivofijo.Administracion")'],
#  ['../trilay/activosfijos\\autorizar_salida1.asp',
#   'autorizar_salida1.asp',
#   288,
#   'Set objtabla = Server.CreateObject("DataCompActivofijo.Administracion")'],
#  ['../trilay/activosfijos\\autorizar_salida1.asp',
#   'autorizar_salida1.asp',
#   330,
#   'Set objtabla1 = Server.CreateObject("DataComprequerimiento.Requerimiento")'],
#  ['../trilay/activosfijos\\autorizar_salida1.asp',
#   'autorizar_salida1.asp',
#   494,
#   'Set objmov = Server.CreateObject("DataCompFondos.Administracion")'],
#  ['../trilay/activosfijos\\autorizar_salida1.asp',
#   'autorizar_salida1.asp',
#   513,
#   '\'Set objtabla1 = Server.CreateObject("DataComprequerimiento.Requerimiento")'],
#  ['../trilay/activosfijos\\comodato_ifr.asp',
#   'comodato_ifr.asp',
#   29,
#   'Set objtabla = server.CreateObject("DataCompActivofijo.administracion")'],
#  ['../trilay/activosfijos\\concepto_admin1.asp',
#   'concepto_admin1.asp',
#   31,
#   'Set objtabla = server.CreateObject("DataCompActivoFijo.administracion")'],
#  ['../trilay/activosfijos\\Detalle_Remito_Gral.asp',
#   'Detalle_Remito_Gral.asp',
#   6,
#   'Set CONN = Server.CreateObject("DataCompSelect.ClaseGeneral")'],
#  ['../trilay/activosfijos\\Detalle_Remito_Gral.asp',
#   'Detalle_Remito_Gral.asp',
#   21,
#   'Set objcarpeta = Server.CreateObject("DataCompAdjuntos.Adjuntos")'],
#  ['../trilay/activosfijos\\entrega_aft1.asp',
#   'entrega_aft1.asp',
#   13,
#   'Set obj3 = Server.CreateObject("DataCompActivofijo.Administracion")'],
#  ['../trilay/activosfijos\\Escritorio_Insumos.asp',
#   'Escritorio_Insumos.asp',
#   56,
#   'SET OBJ = Server.CreateObject("DataCompActivoFijo.Administracion")'],
#  ['../trilay/activosfijos\\Escritorio_Insumos.vb.asp',
#   'Escritorio_Insumos.vb.asp',
#   52,
#   'SET OBJ = Server.CreateObject("DataCompActivoFijo.Administracion")'],
#  ['../trilay/activosfijos\\Escritorio_Insumos.vb.asp',
#   'Escritorio_Insumos.vb.asp',
#   133,
#   'SET OBJ = Server.CreateObject("DataCompActivoFijo.Administracion")'],
#  ['../trilay/activosfijos\\Escritorio_Insumos.vb.asp',
#   'Escritorio_Insumos.vb.asp',
#   206,
#   'SET OBJ = Server.CreateObject("DataCompActivoFijo.Administracion")'],
#  ['../trilay/activosfijos\\Escritorio_Insumos.vb.asp',
#   'Escritorio_Insumos.vb.asp',
#   255,
#   'SET OBJ = Server.CreateObject("DataCompActivoFijo.Administracion")'],
#  ['../trilay/activosfijos\\Escritorio_Insumos.vb.asp',
#   'Escritorio_Insumos.vb.asp',
#   313,
#   'SET OBJ = Server.CreateObject("DataCompActivoFijo.Administracion")'],
#  ['../trilay/activosfijos\\Escritorio_Insumos.vb.asp',
#   'Escritorio_Insumos.vb.asp',
#   987,
#   'SET OBJ = Server.CreateObject("DataCompActivoFijo.Administracion")'],
#  ['../trilay/activosfijos\\estados_modificar.asp',
#   'estados_modificar.asp',
#   69,
#   'Set objgeneral = server.CreateObject("DataCompactivofijo.Administracion")'],
#  ['../trilay/activosfijos\\estados_nuevo.asp',
#   'estados_nuevo.asp',
#   76,
#   'Set objgeneral = server.CreateObject("DataCompactivofijo.Administracion")'],
#  ['../trilay/activosfijos\\estado_admin1.asp',
#   'estado_admin1.asp',
#   32,
#   'Set objtabla2 = server.CreateObject("DataCompActivoFijo.Administracion")'],
#  ['../trilay/activosfijos\\grafico_traslado1.asp',
#   'grafico_traslado1.asp',
#   76,
#   'Set Chart = Server.CreateObject("AspChart.Chart")'],
#  ['../trilay/activosfijos\\Ingreso_Directo.vb.asp',
#   'Ingreso_Directo.vb.asp',
#   59,
#   'Set ObjAF = Server.CreateObject("DataCompActivoFijo.administracion")'],
#  ['../trilay/activosfijos\\Ingreso_Directo.vb.asp',
#   'Ingreso_Directo.vb.asp',
#   311,
#   'Set OBJ = Server.CreateObject("DataCompSelect.clasegeneral")'],
#  ['../trilay/activosfijos\\ingreso_directo_afc1.asp',
#   'ingreso_directo_afc1.asp',
#   40,
#   'Set objcmpc = Server.CreateObject("DataCompCompras.compras")'],
#  ['../trilay/activosfijos\\ingreso_directo_afc1.asp',
#   'ingreso_directo_afc1.asp',
#   43,
#   'set objcomp = Server.CreateObject("DataCompCompras.compras")'],
#  ['../trilay/activosfijos\\ingreso_directo_afc1.asp',
#   'ingreso_directo_afc1.asp',
#   46,
#   'set obj = Server.CreateObject("DataCompCompras.compras")'],
#  ['../trilay/activosfijos\\ingreso_directo_afc1.asp',
#   'ingreso_directo_afc1.asp',
#   49,
#   'Set objtabla3 = Server.CreateObject("DataCompCompras.Compras")'],
#  ['../trilay/activosfijos\\ingreso_directo_afc1.asp',
#   'ingreso_directo_afc1.asp',
#   355,
#   'Set objmov = Server.CreateObject("DataCompFondos.Administracion")'],
#  ['../trilay/activosfijos\\inicial Copy.asp',
#   'inicial Copy.asp',
#   55,
#   'Set objtabla1 = Server.CreateObject("DataCompActivofijo.Administracion")'],
#  ['../trilay/activosfijos\\inicial Copy.asp',
#   'inicial Copy.asp',
#   267,
#   'Set objDocument = Server.CreateObject("Microsoft.XMLDOM")'],
#  ['../trilay/activosfijos\\inicialB Copy.asp',
#   'inicialB Copy.asp',
#   55,
#   'Set objtabla1 = Server.CreateObject("DataCompActivofijo.Administracion")'],
#  ['../trilay/activosfijos\\inicialB Copy.asp',
#   'inicialB Copy.asp',
#   257,
#   'Set objDocument = Server.CreateObject("Microsoft.XMLDOM")'],
#  ['../trilay/activosfijos\\inicialB.asp',
#   'inicialB.asp',
#   36,
#   'Set objtabla1 = Server.CreateObject("DataCompActivofijo.Administracion")'],
#  ['../trilay/activosfijos\\intercambio_compras1.asp',
#   'intercambio_compras1.asp',
#   301,
#   'Set objtabla1 = Server.CreateObject("DataComprequerimiento.Requerimiento")'],
#  ['../trilay/activosfijos\\intercambio_compras1.asp',
#   'intercambio_compras1.asp',
#   304,
#   'Set objcarpeta = Server.CreateObject("DataCompAdjuntos.Adjuntos")'],
#  ['../trilay/activosfijos\\intercambio_compras1.asp',
#   'intercambio_compras1.asp',
#   306,
#   'Set obja = Server.CreateObject("DataCompABC.abc")'],
#  ['../trilay/activosfijos\\intercambio_compras1.asp',
#   'intercambio_compras1.asp',
#   310,
#   'Set objtabla3 = Server.CreateObject("DataCompCompras.Compras")'],
#  ['../trilay/activosfijos\\intercambio_comprasVIEJO.asp',
#   'intercambio_comprasVIEJO.asp',
#   326,
#   'Set objtabla1 = Server.CreateObject("DataComprequerimiento.Requerimiento")'],
#  ['../trilay/activosfijos\\intercambio_comprasVIEJO.asp',
#   'intercambio_comprasVIEJO.asp',
#   329,
#   '\'Set objcarpeta = Server.CreateObject("DataCompAdjuntos.Adjuntos")'],
#  ['../trilay/activosfijos\\intercambio_comprasVIEJO.asp',
#   'intercambio_comprasVIEJO.asp',
#   333,
#   'Set objcomp = Server.CreateObject("DataCompCompras.Compras")'],
#  ['../trilay/activosfijos\\intercambio_comprasVIEJO.asp',
#   'intercambio_comprasVIEJO.asp',
#   336,
#   'Set objtabla3 = Server.CreateObject("DataCompCompras.Compras")'],
#  ['../trilay/activosfijos\\intercambio_Compras_ifr.asp',
#   'intercambio_Compras_ifr.asp',
#   28,
#   'Set objcomp = Server.CreateObject("DataCompCompras.Compras")'],
#  ['../trilay/activosfijos\\listado_fletes.asp',
#   'listado_fletes.asp',
#   8,
#   'Set obj1 = Server.CreateObject("DataCompProduccion.Flete")'],
#  ['../trilay/activosfijos\\listado_lotes.asp',
#   'listado_lotes.asp',
#   47,
#   'Set obj1 = Server.CreateObject("DataCompProduccion.Lote")'],
#  ['../trilay/activosfijos\\listado_lotes.asp',
#   'listado_lotes.asp',
#   63,
#   'Set objmov = Server.CreateObject("DataCompFondos.Administracion")'],
#  ['../trilay/activosfijos\\listado_lotes2.asp',
#   'listado_lotes2.asp',
#   8,
#   'Set obj1 = Server.CreateObject("DataCompProduccion.Lote")'],
#  ['../trilay/activosfijos\\listado_lotes2.asp',
#   'listado_lotes2.asp',
#   44,
#   'Set objmov = Server.CreateObject("DataCompFondos.Administracion")'],
#  ['../trilay/activosfijos\\listado_remitos.asp',
#   'listado_remitos.asp',
#   53,
#   'Set Conn = Server.CreateObject("datacompInventario.GESTION_BD")'],
#  ['../trilay/activosfijos\\listado_remitos.asp',
#   'listado_remitos.asp',
#   189,
#   'Set objmov = Server.CreateObject("DataCompFondos.Administracion")'],
#  ['../trilay/activosfijos\\listaproveedores.asp',
#   'listaproveedores.asp',
#   406,
#   'Set objtabla2 = server.CreateObject("DataCompproveedores.administracion")'],
#  ['../trilay/activosfijos\\organigramarubro.asp',
#   'organigramarubro.asp',
#   78,
#   'Set objorg = Server.CreateObject("DataCompActivoFijo.Organigrama")'],
#  ['../trilay/activosfijos\\organigramarubro.asp',
#   'organigramarubro.asp',
#   90,
#   'Set objDocument = Server.CreateObject("Microsoft.XMLDOM")'],
#  ['../trilay/activosfijos\\organigramarubro1 Copy.asp',
#   'organigramarubro1 Copy.asp',
#   223,
#   'Set objtabla = Server.CreateObject("DataCompActivoFijo.Organigrama")'],
#  ['../trilay/activosfijos\\organigramarubro1 Copy.asp',
#   'organigramarubro1 Copy.asp',
#   227,
#   'Set objorg = Server.CreateObject("DataCompActivoFijo.organigrama")'],
#  ['../trilay/activosfijos\\organigramarubro1 Copy.asp',
#   'organigramarubro1 Copy.asp',
#   247,
#   'Set objDocument = Server.CreateObject("Microsoft.XMLDOM")'],
#  ['../trilay/activosfijos\\organigramarubro1.asp',
#   'organigramarubro1.asp',
#   4,
#   'Set objtabla = Server.CreateObject("DataCompActivoFijo.Organigrama")'],
#  ['../trilay/activosfijos\\orgpermiso.asp',
#   'orgpermiso.asp',
#   83,
#   'Set objDocument = Server.CreateObject("Microsoft.XMLDOM")'],
#  ['../trilay/activosfijos\\orgrubroafc.asp',
#   'orgrubroafc.asp',
#   54,
#   'Set objorg = Server.CreateObject("DataCompActivoFijo.Organigrama")'],
#  ['../trilay/activosfijos\\orgrubroafc.asp',
#   'orgrubroafc.asp',
#   68,
#   'Set objDocument = Server.CreateObject("Microsoft.XMLDOM")'],
#  ['../trilay/activosfijos\\orgrubro_i.asp',
#   'orgrubro_i.asp',
#   35,
#   'set obj1=server.CreateObject("DataCompActivoFijo.Administracion")'],
#  ['../trilay/activosfijos\\preciosIns_admin1.asp',
#   'preciosIns_admin1.asp',
#   40,
#   '\'Set obj_Datos = Server.CreateObject("DataCompActivoFijo.Administracion")'],
#  ['../trilay/activosfijos\\precios_admin.asp',
#   'precios_admin.asp',
#   194,
#   '<%Set obj_Datos = Server.CreateObject("Paging.General")'],
#  ['../trilay/activosfijos\\precios_admin1.asp',
#   'precios_admin1.asp',
#   42,
#   'Set obj_Datos = Server.CreateObject("DataCompActivoFijo.Administracion")'],
#  ['../trilay/activosfijos\\remito_detalle.asp',
#   'remito_detalle.asp',
#   12,
#   'Set CONN = Server.CreateObject("DataCompSelect.ClaseGeneral")'],
#  ['../trilay/activosfijos\\reporte_fletes.asp',
#   'reporte_fletes.asp',
#   17,
#   'Set Conn = Server.CreateObject("DataCompSelect.ClaseGeneral")'],
#  ['../trilay/activosfijos\\resultados_exportar2.asp',
#   'resultados_exportar2.asp',
#   5,
#   'Set obj = Server.CreateObject("DataCompExportarHTML.exportar")'],
#  ['../trilay/activosfijos\\rptmovimiento.asp',
#   'rptmovimiento.asp',
#   32,
#   'set bdd=server.CreateObject("DataCompselect.ClaseGeneral")'],
#  ['../trilay/activosfijos\\rptmovimiento_detallado.asp',
#   'rptmovimiento_detallado.asp',
#   63,
#   'set bdd=server.CreateObject("DataCompSelect.ClaseGeneral")'],
#  ['../trilay/activosfijos\\rubrosjerarquia Copy.asp',
#   'rubrosjerarquia Copy.asp',
#   141,
#   'Set objorg = Server.CreateObject("DataCompActivoFijo.organigrama")'],
#  ['../trilay/activosfijos\\rubrosjerarquia Copy.asp',
#   'rubrosjerarquia Copy.asp',
#   745,
#   'Set objDocument = Server.CreateObject("Microsoft.XMLDOM")'],
#  ['../trilay/activosfijos\\rubros_admin Copy.asp',
#   'rubros_admin Copy.asp',
#   426,
#   'Set objorg = Server.CreateObject("DataCompActivoFijo.Organigrama")'],
#  ['../trilay/activosfijos\\rubros_admin Copy.asp',
#   'rubros_admin Copy.asp',
#   465,
#   'Set objDocument = Server.CreateObject("Microsoft.XMLDOM")'],
#  ['../trilay/activosfijos\\rubros_admin.asp',
#   'rubros_admin.asp',
#   17,
#   'set objtabla= Server.CreateObject("DataCompActivoFijo.Organigrama")'],
#  ['../trilay/activosfijos\\rubros_eliminar.asp',
#   'rubros_eliminar.asp',
#   59,
#   'Set objp = server.CreateObject("DataCompactivofijo.organigrama")'],
#  ['../trilay/activosfijos\\rubros_modificar.asp',
#   'rubros_modificar.asp',
#   20,
#   'Set objp = server.CreateObject("DataCompActivoFijo.organigrama")'],
#  ['../trilay/activosfijos\\rubros_nuevo.asp',
#   'rubros_nuevo.asp',
#   25,
#   'Set objp = server.CreateObject("DataCompActivoFijo.organigrama")'],
#  ['../trilay/activosfijos\\rubros_nuevo1.asp',
#   'rubros_nuevo1.asp',
#   36,
#   'Set objp = server.CreateObject("DataCompActivoFijo.organigrama")'],
#  ['../trilay/activosfijos\\rubros_nuevo1.asp',
#   'rubros_nuevo1.asp',
#   44,
#   'Set obja = server.CreateObject("DataCompActivoFijo.Administracion")'],
#  ['../trilay/activosfijos\\Salida_Directa.vb.asp',
#   'Salida_Directa.vb.asp',
#   63,
#   'Set ObjAF = Server.CreateObject("DataCompActivoFijo.administracion")'],
#  ['../trilay/activosfijos\\sel_articulojerarquia_nuevo.asp',
#   'sel_articulojerarquia_nuevo.asp',
#   135,
#   'Set objtabla1 = server.CreateObject("DataCompactivofijo.administracion")'],
#  ['../trilay/activosfijos\\sel_articulojerarquia_nuevo.asp',
#   'sel_articulojerarquia_nuevo.asp',
#   173,
#   'Set objgeneral = server.CreateObject("DataCompcompras.Administracion")'],
#  ['../trilay/activosfijos\\sel_articulopropio.asp',
#   'sel_articulopropio.asp',
#   138,
#   'Set objtabla1 = server.CreateObject("DataCompactivofijo.administracion")'],
#  ['../trilay/activosfijos\\sel_articulopropio.asp',
#   'sel_articulopropio.asp',
#   178,
#   'Set objgeneral = server.CreateObject("DataCompcompras.Administracion")'],
#  ['../trilay/activosfijos\\sel_articulo_nuevo.asp',
#   'sel_articulo_nuevo.asp',
#   9,
#   'Set objtabla = Server.CreateObject("DataCompCompras.Compras")'],
#  ['../trilay/activosfijos\\sel_articulo_nuevo_ifr.asp',
#   'sel_articulo_nuevo_ifr.asp',
#   10,
#   'Set objtabla = Server.CreateObject("DataCompCompras.Compras")'],
#  ['../trilay/activosfijos\\sel_articulo_seleccion1.asp',
#   'sel_articulo_seleccion1.asp',
#   65,
#   'Set objorg = Server.CreateObject("DataCompactivofijo.organigrama")'],
#  ['../trilay/activosfijos\\sel_articulo_seleccion1.asp',
#   'sel_articulo_seleccion1.asp',
#   214,
#   'Set objDocument = Server.CreateObject("Microsoft.XMLDOM")'],
#  ['../trilay/activosfijos\\stockinsumosprod_admin.asp',
#   'stockinsumosprod_admin.asp',
#   11,
#   'Set objcarpeta = Server.CreateObject("DataCompAdjuntos.Adjuntos")'],
#  ['../trilay/activosfijos\\stockinsumosprod_admin_old.asp',
#   'stockinsumosprod_admin_old.asp',
#   15,
#   'Set objcarpeta = Server.CreateObject("DataCompAdjuntos.Adjuntos")'],
#  ['../trilay/activosfijos\\Transformacion_Productos.vb.asp',
#   'Transformacion_Productos.vb.asp',
#   48,
#   'Set ObjInv = New Conexion\'Server.CreateObject("DataCompInventario.administracion")'],
#  ['../trilay/activosfijos\\Traslado_Insumos.vb.asp',
#   'Traslado_Insumos.vb.asp',
#   31,
#   'Set ObjAF = Server.CreateObject("DataCompActivoFijo.administracion")'],
#  ['../trilay/activosfijos\\Traslado_Insumos.vb.asp',
#   'Traslado_Insumos.vb.asp',
#   285,
#   'Set OBJ = Server.CreateObject("DataCompActivoFijo.administracion")'],
#  ['../trilay/activosfijos\\Traslado_Insumos.vb.asp',
#   'Traslado_Insumos.vb.asp',
#   418,
#   'Set OBJ = Server.CreateObject("DataCompActivoFijo.administracion")'],
#  ['../trilay/activosfijos\\Traslado_Insumos.vb.asp',
#   'Traslado_Insumos.vb.asp',
#   716,
#   'Set Conn = Server.CreateObject("datacompInventario.GESTION_BD")'],
#  ['../trilay/activosfijos\\Traslado_Insumos_Especial.vb.asp',
#   'Traslado_Insumos_Especial.vb.asp',
#   40,
#   'Set ObjAF = Server.CreateObject("DataCompActivoFijo.administracion")'],
#  ['../trilay/activosfijos\\Traslado_Insumos_Especial.vb.asp',
#   'Traslado_Insumos_Especial.vb.asp',
#   526,
#   'Set Conn = New Conexion\'Server.CreateObject("datacompInventario.GESTION_BD")'],
#  ['../trilay/activosfijos\\Reporte\\AlwaysRequiredSteps.asp',
#   'AlwaysRequiredSteps.asp',
#   21,
#   'Set session("oApp") = Server.CreateObject("CrystalRuntime.Application")'],
#  ['../trilay/activosfijos\\Reporte\\rptserver.asp',
#   'rptserver.asp',
#   71,
#   'Set session("oEMF") = Server.CreateObject("CREmfgen.CREmfgen.1")']]

# %%
# Create a DataFrame
columns = ["Path", "File", "Line Number", "Code Line"]
df = pd.DataFrame(data, columns=columns)

# Export to Excel
df.to_excel(output_file, index=False, engine="openpyxl")

print(f"Data successfully exported to {output_file}")
# Out:
# Data successfully exported to output.xlsx
